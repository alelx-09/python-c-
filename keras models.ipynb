# %%
#more data

model = Sequential()

percent_noise = 0.1
noise = (1.0/255) * percent_noise
model.add(GaussianNoise(noise, input_shape=(200,200,1)))
model.add(BatchNormalization())
#Layer 1
model.add(Convolution2D(6, 3, 3))
model.add(LeakyReLU(alpha= 0.1))

#Layer 2
model.add(Convolution2D(8, 3, 3, border_mode='same')) 
model.add(LeakyReLU(alpha= 0.1))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
#Layer 3
model.add(Convolution2D(9, 3, 3, border_mode='same')) 
model.add(LeakyReLU(alpha= 0.1))
model.add(Dropout(0.25))

#Layer 4
model.add(Convolution2D(12, 3, 3, border_mode='same')) 
model.add(LeakyReLU(alpha= 0.2))
model.add(BatchNormalization())

#Layer 5
model.add(Convolution2D(18, 3, 3, border_mode='same')) 
model.add(LeakyReLU(alpha= 0.1)) 
model.add(MaxPooling2D(pool_size=(2, 2)))
#Layer 6
model.add(Flatten()) 
model.add(Dense(27, init='glorot_normal'))
model.add(LeakyReLU(alpha= 0.1)) 
model.add(Dropout(0.5))
model.add(BatchNormalization())
#Layer 7
model.add(Dense(55, init='glorot_normal')) 
model.add(LeakyReLU(alpha= 0.1))
model.add(Dropout(0.5))
#Layer 8
model.add(Dense(9, init='glorot_normal'))
model.add(Activation('softmax'))

# %%
#alpha 
import numpy as np
model = Sequential()

percent_noise = 0.1
noise = (1.0/255) * percent_noise
model.add(GaussianNoise(noise, input_shape=(200,200,1)))
#Layer 1
model.add(Convolution2D(6, 3, 3))
model.add(LeakyReLU(alpha= 0.1))
#Layer 2
model.add(Convolution2D(8, 3, 3, border_mode='same')) 
model.add(LeakyReLU(alpha= 0.1))
model.add(MaxPooling2D(pool_size=(2, 2)))
#Layer 3
model.add(Convolution2D(12, 3, 3, border_mode='same')) 
model.add(LeakyReLU(alpha= 0.1))
#Layer 4
model.add(Convolution2D(19, 3, 3, border_mode='same')) 
model.add(LeakyReLU(alpha= 0.1))
#Layer 5
model.add(Convolution2D(22, 3, 3, border_mode='same')) 
model.add(LeakyReLU(alpha= 0.1)) 
model.add(MaxPooling2D(pool_size=(2, 2)))
#Layer 6
model.add(Flatten()) 
model.add(Dense(47, init='glorot_normal'))
model.add(LeakyReLU(alpha= 0.1)) 
model.add(Dropout(0.5))
#Layer 7
model.add(Dense(55, init='glorot_normal')) 
model.add(LeakyReLU(alpha= 0.1))
model.add(Dropout(0.5))
#Layer 8
model.add(Dense(9, init='glorot_normal'))
model.add(Activation('softmax'))

# %%
model = Sequential()

percent_noise = 0.1
noise = (1.0/255) * percent_noise
model.add(GaussianNoise(noise, input_shape=(200,200,1)))
model.add(LeakyReLU(alpha= 0.1))
model.add(BatchNormalization())

model.add(Convolution2D(32, 3, 3, border_mode='same')) 
model.add(LeakyReLU(alpha= 0.1))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())

model.add(Convolution2D(32, 3, 3, border_mode='same')) 
model.add(LeakyReLU(alpha= 0.1))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())

model.add(Convolution2D(64, 3, 3, border_mode='same')) 
model.add(LeakyReLU(alpha= 0.1))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())

model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(64,))
model.add(LeakyReLU(alpha= 0.1))
model.add(Dropout(0.5))
model.add(Dense(9, activation='softmax'))
